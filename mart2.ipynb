# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("mart.csv")

# %%
dataset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
x=dataset.iloc[:,1:-1]
y=dataset.iloc[:,-1]

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
x
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
d = {
    
    'Low Fat' : 0,
    'Regular' : 1
}

x['Item_Fat_Content'] = x['Item_Fat_Content'].map(d)

# %%
d = {
    
    'Grocery Store' : 0,
    'Supermarket Type1' : 1,
    'Supermarket Type2' : 2,
    'Supermarket Type3' : 3
}

x['Outlet_Type'] = x['Outlet_Type'].map(d)

# %%
d = {
    
    'tier 1' : 1,
    'tier 2' : 2,
    'tier 3' : 3
    
}
x['Outlet_Location_Type'] = x['Outlet_Location_Type'].map(d)

# %%
d = {
    
    'Medium' :1,
    'High' : 2,
    'Small' : 0
}

x['Outlet_Size'] = x['Outlet_Size'].map(d)

# %%
d = {
    
    'Dairy' : 0,
    'Soft Drinks' : 1,
    'Meat' : 2,
    'Fruits and Vegetables' : 3,
    'Household' : 4,
    'Baking Goods' : 5,
    'Snack Foods' : 6,
    'Frozen Foods' : 7,
    'Breakfast' : 8,
    'Health and Hygiene' : 9,
    'Hard Drinks' : 10,
    'Canned' : 11,
    'Breads' : 12,
    'Starchy Foods' : 13,
    'Others' : 14,
    'Seafood' : 15 
    
}

x['Item_Type'] = x['Item_Type'].map(d)

# %%
x
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300               0.0         0.016047          0  249.8092
# 1           5.920               1.0         0.019278          1   48.2692
# 2          17.500               0.0         0.016760          2  141.6180
# 3          19.200               1.0         0.000000          3  182.0950
# 4           8.930               0.0         0.000000          4   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865               0.0         0.056783          6  214.5218
# 8519        8.380               1.0         0.046982          5  108.1570
# 8520       10.600               0.0         0.035186          9   85.1224
# 8521        7.210               1.0         0.145221          6  103.1332
# 8522       14.800               0.0         0.044878          1   75.4670
#
#      Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
x.drop(['Outlet_Identifier','Outlet_Location_Type'],axis=1,inplace=True)

# %%
x
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300               0.0         0.016047          0  249.8092
# 1           5.920               1.0         0.019278          1   48.2692
# 2          17.500               0.0         0.016760          2  141.6180
# 3          19.200               1.0         0.000000          3  182.0950
# 4           8.930               0.0         0.000000          4   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865               0.0         0.056783          6  214.5218
# 8519        8.380               1.0         0.046982          5  108.1570
# 8520       10.600               0.0         0.035186          9   85.1224
# 8521        7.210               1.0         0.145221          6  103.1332
# 8522       14.800               0.0         0.044878          1   75.4670
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Type
# ...

# %%
x = x.fillna(x.mean())

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn import preprocessing
from sklearn import utils
lab = preprocessing.LabelEncoder()
y_train = lab.fit_transform(y_train)

# %%
x
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300               0.0         0.016047          0  249.8092
# 1           5.920               1.0         0.019278          1   48.2692
# 2          17.500               0.0         0.016760          2  141.6180
# 3          19.200               1.0         0.000000          3  182.0950
# 4           8.930               0.0         0.000000          4   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865               0.0         0.056783          6  214.5218
# 8519        8.380               1.0         0.046982          5  108.1570
# 8520       10.600               0.0         0.035186          9   85.1224
# 8521        7.210               1.0         0.145221          6  103.1332
# 8522       14.800               0.0         0.044878          1   75.4670
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Type
# ...

# %%
y_train
# Out:
# array([ 140, 2021, 2683, ..., 1077, 2039, 2534], dtype=int64)

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='rbf',random_state=0)
classifier.fit(x_train,y_train)
# Out:
# SVC(random_state=0)

# %%
print(classifier.predict([[5.920 ,1.0 ,0.019278 ,1 ,48.2692 ,2009 ,1.000000 ,2]]))
# Out:
# [1319]
